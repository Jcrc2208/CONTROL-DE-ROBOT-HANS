# %% [markdown]
# <a href="https://colab.research.google.com/github/Jcrc2208/CONTROL-DE-ROBOT-HANS/blob/interfaz-ui/pieza_metalica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Inicializar cuenta de Github**

# %%
# !git config --global user.name "marcooramoslana-dev"
# !git config --global user.email "marcooramoslana@gmail.com"

# %% [markdown]
# **Clonar repositorio**

# %%
# !git clone https://github.com/Jcrc2208/CONTROL-DE-ROBOT-HANS.git
# Out:
# Cloning into 'CONTROL-DE-ROBOT-HANS'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 102 (delta 32), reused 87 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 3.02 MiB | 34.00 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd CONTROL-DE-ROBOT-HANS
# Out:
# /content/CONTROL-DE-ROBOT-HANS

# %% [markdown]
# **Conectar Google Colab con Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Copiar y descomprimir el .zip en Colab**

# %%
# Copiar el zip
# !cp "/content/drive/MyDrive/data.zip" /content/

# Descomprimir
# !unzip -q /content/data.zip -d /content/

# %% [markdown]
# **Ver si se creo la carpeta**

# %%
# !ls
# Out:
# coords_log.csv	dataset_yolo  data.yaml  docs  modelos	src

# %%
# %cd /content/CONTROL-DE-ROBOT-HANS
# Out:
# /content/CONTROL-DE-ROBOT-HANS

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/interfaz-ui
#   remotes/origin/main
#   remotes/origin/rama-nube

# %%
# %cd /content/CONTROL-DE-ROBOT-HANS
# Out:
# /content/CONTROL-DE-ROBOT-HANS

# %%
# !git checkout interfaz-ui
# Out:
# Branch 'interfaz-ui' set up to track remote branch 'interfaz-ui' from 'origin'.
# Switched to a new branch 'interfaz-ui'

# %% [markdown]
# **Estrucura del proyecto**

# %%
# !apt-get install tree -y
# !tree

# %%
# !pip install ultralytics

# %% [markdown]
# **Fine-Tuning**

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/CONTROL-DE-ROBOT-HANS/data.yaml',   # Ruta de tu data.yaml
    epochs=50,
    imgsz=640,                                         # Tamaño estándar de entrada para las imágenes
    device=0                                           # Indica a Colab que use la GPU integrada
)
